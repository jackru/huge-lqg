# %% [markdown]
# TO DO:
#  - add simple mean evaluation back in
#  - add datasets with interactions

# %% [markdown]
# # Multi-model comparison (initially on toy data)
#  - Data is provided/generated in sci-kit learn friendly format (not including constant?)
#  - Implements a train/test split or similar
#  - Tries prediction using a list of models that is provided
#  - Outputs metrics
#   - RMSE, MAE, training and prediction time

# %% [markdown]
# # Imports

# %%
# %load_ext autoreload
# %autoreload 1

# %%
import os
import time

import graphviz
import matplotlib
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
from pygam import LinearGAM, PoissonGAM, s, f
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.neighbors import KNeighborsRegressor
from sklearn.neural_network import MLPRegressor
import statsmodels.api as sm
from statsmodels.tools.eval_measures import mse
from xgboost import XGBRegressor

# %aimport model_wrappers, toy_data_generation, param_dict_generation
from model_wrappers import try_scikit_model, try_statsmodels_model
from toy_data_generation import generate_linear_data, generate_poisson_data
from param_dict_generation import generate_ols_list, generate_glm_list, generate_mlp_list, generate_xgb_list

# %matplotlib inline

# %%
pd.set_option('display.max_rows', 1000)
pd.set_option('display.max_columns', 500)

# %% [markdown]
# # Data generation

# %%
datasets = []
for nrows in [10000, 30000]:
    for nvars in [30, 100]:
#         datasets.append((*generate_linear_data(nrows, nvars), f'linear_{nvars}vars_{nrows}rows'))
        datasets.append((*generate_poisson_data(nrows, nvars,
                                                binary_fraction=0.5,
                                                binary_imbalance=10),
                         f'poisson_{nvars}vars_{nrows}rows'))

# %% [markdown]
# # Experiment lists

# %% [markdown]
# ## Statsmodels list

# %%
ols_list = generate_ols_list(alpha_list=[1,2,3], L1_wt_list=[0,0.5,1])

glm_list = generate_glm_list('Poisson', alpha_list=[0.001,0.01,0.1])

statsmodels_param_list = ols_list + glm_list

# %% [markdown]
# ## Scikit list

# %%
mlp_list = generate_mlp_list(hidden_layout_list=[(50,), (20, 20)])

xgb_list = generate_xgb_list(depth_list = [2,4,6],
                             learning_rate_list = [0.01, 0.3],
                             objective='Poisson',
                             early_stopping_rounds=5)

scikit_param_list = mlp_list + xgb_list

# %% [markdown]
# # Minimal Interesting Product

# %%
def mip(X_train, X_test, y_train, y_test, statsmodels_list=None, scikit_list=None):
    results = {}
    for trial in statsmodels_list:
        try:
            results[f"{trial['model_name']}"] = try_statsmodels_model(X_train, X_test, y_train, y_test, trial)
        except:
            print(f'An error occured with {trial["model_name"]}')
    for trial in scikit_list:
        results[f"{trial['model_name']}"] = try_scikit_model(X_train, X_test, y_train, y_test, trial)
    return results

# %% [markdown]
# # Loop over datasets

# %%
results = {}

for X, y, dataset_name in datasets:
    print(f'\n\n{dataset_name}\n')
    # update scikit_param_list for xgboost early stopping eval_sets if present
    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=303)
    model_results = mip(
        X_train, X_test, y_train, y_test,
        statsmodels_list=statsmodels_param_list, scikit_list=scikit_param_list
    )
    for key in model_results:
        results[(dataset_name, key)] = model_results[key]
    
display(pd.DataFrame(results).T)
# Out:
# poisson_30vars_10000rows
#
# OLS_no_reg trained in 0.03 seconds
# OLS_alpha_1_L1_0 trained in 0.02 seconds
# OLS_alpha_1_L1_0.5 trained in 0.03 seconds
# OLS_alpha_1_L1_1 trained in 0.03 seconds
# OLS_alpha_2_L1_0 trained in 0.02 seconds
# OLS_alpha_2_L1_0.5 trained in 0.03 seconds
# OLS_alpha_2_L1_1 trained in 0.03 seconds
# OLS_alpha_3_L1_0 trained in 0.02 seconds
# OLS_alpha_3_L1_0.5 trained in 0.04 seconds
# OLS_alpha_3_L1_1 trained in 0.07 seconds
# GLM_Poisson_no_reg trained in 0.16 seconds
# GLM_Poisson_alpha_0.001 trained in 0.77 seconds
# GLM_Poisson_alpha_0.01 trained in 0.26 seconds
# GLM_Poisson_alpha_0.1 trained in 0.23 seconds
# MLP_50 trained in 0.51 seconds
# MLP_20_20 trained in 0.41 seconds
# XGB_Poisson_maxd_2_lr_0.01 trained in 0.62 seconds
# XGB_Poisson_maxd_2_lr_0.3 trained in 0.22 seconds
# XGB_Poisson_maxd_4_lr_0.01 trained in 1.05 seconds
# XGB_Poisson_maxd_4_lr_0.3 trained in 0.27 seconds
# XGB_Poisson_maxd_6_lr_0.01 trained in 1.33 seconds
# XGB_Poisson_maxd_6_lr_0.3 trained in 0.39 seconds
#
#
# poisson_100vars_10000rows
#
# OLS_no_reg trained in 0.12 seconds
# OLS_alpha_1_L1_0 trained in 0.12 seconds
# OLS_alpha_1_L1_0.5 trained in 0.11 seconds
# OLS_alpha_1_L1_1 trained in 0.12 seconds
# OLS_alpha_2_L1_0 trained in 0.12 seconds
# OLS_alpha_2_L1_0.5 trained in 0.12 seconds
# OLS_alpha_2_L1_1 trained in 0.12 seconds
# OLS_alpha_3_L1_0 trained in 0.12 seconds
# OLS_alpha_3_L1_0.5 trained in 0.12 seconds
# OLS_alpha_3_L1_1 trained in 0.12 seconds
# /home/arthurjackrussell/repos/customer-deliverables/bm-venv/lib/python3.6/site-packages/statsmodels/genmod/families/links.py:477: RuntimeWarning: overflow encountered in exp
#   return np.exp(z)
# /home/arthurjackrussell/repos/customer-deliverables/bm-venv/lib/python3.6/site-packages/statsmodels/genmod/families/family.py:131: RuntimeWarning: invalid value encountered in multiply
#   return 1. / (self.link.deriv(mu)**2 * self.variance(mu))
# /home/arthurjackrussell/repos/customer-deliverables/bm-venv/lib/python3.6/site-packages/statsmodels/genmod/generalized_linear_model.py:1129: RuntimeWarning: invalid value encountered in multiply
#   - self._offset_exposure)
# An error occured with GLM_Poisson_no_reg
# GLM_Poisson_alpha_0.001 trained in 2.84 seconds
# GLM_Poisson_alpha_0.01 trained in 0.86 seconds
# GLM_Poisson_alpha_0.1 trained in 0.76 seconds
# MLP_50 trained in 1.23 seconds
# MLP_20_20 trained in 0.53 seconds
# XGB_Poisson_maxd_2_lr_0.01 trained in 1.94 seconds
# XGB_Poisson_maxd_2_lr_0.3 trained in 0.50 seconds
# XGB_Poisson_maxd_4_lr_0.01 trained in 3.46 seconds
# XGB_Poisson_maxd_4_lr_0.3 trained in 0.84 seconds
# XGB_Poisson_maxd_6_lr_0.01 trained in 5.00 seconds
# XGB_Poisson_maxd_6_lr_0.3 trained in 1.08 seconds
#
#
# poisson_30vars_30000rows
#
# OLS_no_reg trained in 0.07 seconds
# OLS_alpha_1_L1_0 trained in 0.07 seconds
# OLS_alpha_1_L1_0.5 trained in 0.07 seconds
# OLS_alpha_1_L1_1 trained in 0.06 seconds
# OLS_alpha_2_L1_0 trained in 0.05 seconds
# OLS_alpha_2_L1_0.5 trained in 0.05 seconds
# OLS_alpha_2_L1_1 trained in 0.06 seconds
# OLS_alpha_3_L1_0 trained in 0.06 seconds
# OLS_alpha_3_L1_0.5 trained in 0.05 seconds
# OLS_alpha_3_L1_1 trained in 0.05 seconds
# GLM_Poisson_no_reg trained in 0.23 seconds
# GLM_Poisson_alpha_0.001 trained in 1.19 seconds
# GLM_Poisson_alpha_0.01 trained in 0.72 seconds
# GLM_Poisson_alpha_0.1 trained in 0.61 seconds
# MLP_50 trained in 1.13 seconds
# MLP_20_20 trained in 0.54 seconds
# XGB_Poisson_maxd_2_lr_0.01 trained in 1.85 seconds
# XGB_Poisson_maxd_2_lr_0.3 trained in 0.77 seconds
# XGB_Poisson_maxd_4_lr_0.01 trained in 2.66 seconds
# XGB_Poisson_maxd_4_lr_0.3 trained in 0.98 seconds
# XGB_Poisson_maxd_6_lr_0.01 trained in 3.05 seconds
# XGB_Poisson_maxd_6_lr_0.3 trained in 1.16 seconds
#
#
# poisson_100vars_30000rows
#
# OLS_no_reg trained in 0.36 seconds
# OLS_alpha_1_L1_0 trained in 0.33 seconds
# OLS_alpha_1_L1_0.5 trained in 0.27 seconds
# OLS_alpha_1_L1_1 trained in 0.27 seconds
# OLS_alpha_2_L1_0 trained in 0.33 seconds
# OLS_alpha_2_L1_0.5 trained in 0.27 seconds
# OLS_alpha_2_L1_1 trained in 0.27 seconds
# OLS_alpha_3_L1_0 trained in 0.33 seconds
# OLS_alpha_3_L1_0.5 trained in 0.27 seconds
# OLS_alpha_3_L1_1 trained in 0.27 seconds
# GLM_Poisson_no_reg trained in 2.95 seconds
# GLM_Poisson_alpha_0.001 trained in 6.81 seconds
# GLM_Poisson_alpha_0.01 trained in 2.17 seconds
# GLM_Poisson_alpha_0.1 trained in 1.94 seconds
# MLP_50 trained in 1.52 seconds
# MLP_20_20 trained in 1.04 seconds
# XGB_Poisson_maxd_2_lr_0.01 trained in 5.45 seconds
# XGB_Poisson_maxd_2_lr_0.3 trained in 1.96 seconds
# XGB_Poisson_maxd_4_lr_0.01 trained in 10.06 seconds
# XGB_Poisson_maxd_4_lr_0.3 trained in 2.35 seconds
# XGB_Poisson_maxd_6_lr_0.01 trained in 14.37 seconds
# XGB_Poisson_maxd_6_lr_0.3 trained in 3.80 seconds
#                                                       mse_test  \
# poisson_30vars_10000rows  OLS_no_reg                  0.010559
#                           OLS_alpha_1_L1_0            0.010562
#                           OLS_alpha_1_L1_0.5          0.010667
#                           OLS_alpha_1_L1_1            0.010667
#                           OLS_alpha_2_L1_0            0.010588
#                           OLS_alpha_2_L1_0.5          0.010667
#                           OLS_alpha_2_L1_1            0.010667
#                           OLS_alpha_3_L1_0            0.010604
#                           OLS_alpha_3_L1_0.5          0.010667
#                           OLS_alpha_3_L1_1            0.010667
#                           GLM_Poisson_no_reg          0.010553
#                           GLM_Poisson_alpha_0.001     0.010549
#                           GLM_Poisson_alpha_0.01      0.010669
#                           GLM_Poisson_alpha_0.1       0.020706
#                           MLP_50                      0.012207
#                           MLP_20_20                   0.011976
#                           XGB_Poisson_maxd_2_lr_0.01  0.043233
#                           XGB_Poisson_maxd_2_lr_0.3   0.010482
#                           XGB_Poisson_maxd_4_lr_0.01  0.043243
#                           XGB_Poisson_maxd_4_lr_0.3   0.010525
#                           XGB_Poisson_maxd_6_lr_0.01  0.043243
#                           XGB_Poisson_maxd_6_lr_0.3   0.010646
# poisson_100vars_10000rows OLS_no_reg                  0.012696
#                           OLS_alpha_1_L1_0            0.012492
#                           OLS_alpha_1_L1_0.5          0.012667
#                           OLS_alpha_1_L1_1            0.012667
#                           OLS_alpha_2_L1_0            0.012526
#                           OLS_alpha_2_L1_0.5          0.012667
#                           OLS_alpha_2_L1_1            0.012667
#                           OLS_alpha_3_L1_0            0.012549
#                           OLS_alpha_3_L1_0.5          0.012667
#                           OLS_alpha_3_L1_1            0.012667
#                           GLM_Poisson_alpha_0.001     0.012522
#                           GLM_Poisson_alpha_0.01      0.012631
#                           GLM_Poisson_alpha_0.1       0.022746
#                           MLP_50                      0.018979
#                           MLP_20_20                   0.013929
#                           XGB_Poisson_maxd_2_lr_0.01  0.045029
#                           XGB_Poisson_maxd_2_lr_0.3   0.012537
#                           XGB_Poisson_maxd_4_lr_0.01  0.045206
#                           XGB_Poisson_maxd_4_lr_0.3   0.012630
#                           XGB_Poisson_maxd_6_lr_0.01  0.045363
#                           XGB_Poisson_maxd_6_lr_0.3   0.012554
# poisson_30vars_30000rows  OLS_no_reg                  0.010221
#                           OLS_alpha_1_L1_0            0.010234
#                           OLS_alpha_1_L1_0.5          0.010333
#                           OLS_alpha_1_L1_1            0.010333
#                           OLS_alpha_2_L1_0            0.010255
#                           OLS_alpha_2_L1_0.5          0.010333
#                           OLS_alpha_2_L1_1            0.010333
#                           OLS_alpha_3_L1_0            0.010269
#                           OLS_alpha_3_L1_0.5          0.010333
#                           OLS_alpha_3_L1_1            0.010333
#                           GLM_Poisson_no_reg          0.010232
#                           GLM_Poisson_alpha_0.001     0.010231
#                           GLM_Poisson_alpha_0.01      0.010358
#                           GLM_Poisson_alpha_0.1       0.020487
#                           MLP_50                      0.011322
#                           MLP_20_20                   0.010694
#                           XGB_Poisson_maxd_2_lr_0.01  0.043006
#                           XGB_Poisson_maxd_2_lr_0.3   0.010229
#                           XGB_Poisson_maxd_4_lr_0.01  0.043017
#                           XGB_Poisson_maxd_4_lr_0.3   0.010241
#                           XGB_Poisson_maxd_6_lr_0.01  0.043039
#                           XGB_Poisson_maxd_6_lr_0.3   0.010309
# poisson_100vars_30000rows OLS_no_reg                  0.014667
#                           OLS_alpha_1_L1_0            0.014769
#                           OLS_alpha_1_L1_0.5          0.015000
#                           OLS_alpha_1_L1_1            0.015000
#                           OLS_alpha_2_L1_0            0.014820
#                           OLS_alpha_2_L1_0.5          0.015000
#                           OLS_alpha_2_L1_1            0.015000
#                           OLS_alpha_3_L1_0            0.014852
#                           OLS_alpha_3_L1_0.5          0.015000
#                           OLS_alpha_3_L1_1            0.015000
#                           GLM_Poisson_no_reg          0.014650
#                           GLM_Poisson_alpha_0.001     0.014728
#                           GLM_Poisson_alpha_0.01      0.014869
#                           GLM_Poisson_alpha_0.1       0.024655
#                           MLP_50                      0.015912
#                           MLP_20_20                   0.015277
#                           XGB_Poisson_maxd_2_lr_0.01  0.046539
#                           XGB_Poisson_maxd_2_lr_0.3   0.014728
#                           XGB_Poisson_maxd_4_lr_0.01  0.046612
#                           XGB_Poisson_maxd_4_lr_0.3   0.014848
#                           XGB_Poisson_maxd_6_lr_0.01  0.046659
#                           XGB_Poisson_maxd_6_lr_0.3   0.014830
#
#                                                       prediction_time  \
# poisson_30vars_10000rows  OLS_no_reg                         0.001646
#                           OLS_alpha_1_L1_0                   0.001289
#                           OLS_alpha_1_L1_0.5                 0.001417
#                           OLS_alpha_1_L1_1                   0.001384
#                           OLS_alpha_2_L1_0                   0.001364
#                           OLS_alpha_2_L1_0.5                 0.001412
#                           OLS_alpha_2_L1_1                   0.001531
#                           OLS_alpha_3_L1_0                   0.001471
#                           OLS_alpha_3_L1_0.5                 0.001635
#                           OLS_alpha_3_L1_1                   0.001395
#                           GLM_Poisson_no_reg                 0.001594
#                           GLM_Poisson_alpha_0.001            0.001855
#                           GLM_Poisson_alpha_0.01             0.001841
#                           GLM_Poisson_alpha_0.1              0.001856
#                           MLP_50                             0.005707
#                           MLP_20_20                          0.002805
#                           XGB_Poisson_maxd_2_lr_0.01         0.004971
#                           XGB_Poisson_maxd_2_lr_0.3          0.003244
#                           XGB_Poisson_maxd_4_lr_0.01         0.007728
#                           XGB_Poisson_maxd_4_lr_0.3          0.002878
#                           XGB_Poisson_maxd_6_lr_0.01         0.006938
#                           XGB_Poisson_maxd_6_lr_0.3          0.003443
# poisson_100vars_10000rows OLS_no_reg                         0.003109
#                           OLS_alpha_1_L1_0                   0.002691
#                           OLS_alpha_1_L1_0.5                 0.002861
#                           OLS_alpha_1_L1_1                   0.002999
#                           OLS_alpha_2_L1_0                   0.002649
#                           OLS_alpha_2_L1_0.5                 0.003084
#                           OLS_alpha_2_L1_1                   0.002905
#                           OLS_alpha_3_L1_0                   0.002965
#                           OLS_alpha_3_L1_0.5                 0.003100
#                           OLS_alpha_3_L1_1                   0.003164
#                           GLM_Poisson_alpha_0.001            0.003108
#                           GLM_Poisson_alpha_0.01             0.003161
#                           GLM_Poisson_alpha_0.1              0.003076
#                           MLP_50                             0.005085
#                           MLP_20_20                          0.003985
#                           XGB_Poisson_maxd_2_lr_0.01         0.007605
#                           XGB_Poisson_maxd_2_lr_0.3          0.004279
#                           XGB_Poisson_maxd_4_lr_0.01         0.008880
#                           XGB_Poisson_maxd_4_lr_0.3          0.004807
#                           XGB_Poisson_maxd_6_lr_0.01         0.012536
#                           XGB_Poisson_maxd_6_lr_0.3          0.005506
# poisson_30vars_30000rows  OLS_no_reg                         0.003301
#                           OLS_alpha_1_L1_0                   0.002890
#                           OLS_alpha_1_L1_0.5                 0.003171
#                           OLS_alpha_1_L1_1                   0.002760
#                           OLS_alpha_2_L1_0                   0.002305
#                           OLS_alpha_2_L1_0.5                 0.002817
#                           OLS_alpha_2_L1_1                   0.002867
#                           OLS_alpha_3_L1_0                   0.002242
#                           OLS_alpha_3_L1_0.5                 0.002875
#                           OLS_alpha_3_L1_1                   0.002758
#                           GLM_Poisson_no_reg                 0.003146
#                           GLM_Poisson_alpha_0.001            0.003440
#                           GLM_Poisson_alpha_0.01             0.003463
#                           GLM_Poisson_alpha_0.1              0.003724
#                           MLP_50                             0.007833
#                           MLP_20_20                          0.006057
#                           XGB_Poisson_maxd_2_lr_0.01         0.011169
#                           XGB_Poisson_maxd_2_lr_0.3          0.009302
#                           XGB_Poisson_maxd_4_lr_0.01         0.014021
#                           XGB_Poisson_maxd_4_lr_0.3          0.008723
#                           XGB_Poisson_maxd_6_lr_0.01         0.016202
#                           XGB_Poisson_maxd_6_lr_0.3          0.009658
# poisson_100vars_30000rows OLS_no_reg                         0.007549
#                           OLS_alpha_1_L1_0                   0.007486
#                           OLS_alpha_1_L1_0.5                 0.007338
#                           OLS_alpha_1_L1_1                   0.007333
#                           OLS_alpha_2_L1_0                   0.007623
#                           OLS_alpha_2_L1_0.5                 0.007730
#                           OLS_alpha_2_L1_1                   0.007250
#                           OLS_alpha_3_L1_0                   0.007057
#                           OLS_alpha_3_L1_0.5                 0.007099
#                           OLS_alpha_3_L1_1                   0.007172
#                           GLM_Poisson_no_reg                 0.017936
#                           GLM_Poisson_alpha_0.001            0.007422
#                           GLM_Poisson_alpha_0.01             0.007522
#                           GLM_Poisson_alpha_0.1              0.007505
#                           MLP_50                             0.012471
#                           MLP_20_20                          0.008995
#                           XGB_Poisson_maxd_2_lr_0.01         0.026892
#                           XGB_Poisson_maxd_2_lr_0.3          0.014611
#                           XGB_Poisson_maxd_4_lr_0.01         0.027826
#                           XGB_Poisson_maxd_4_lr_0.3          0.014881
#                           XGB_Poisson_maxd_6_lr_0.01         0.032538
#                           XGB_Poisson_maxd_6_lr_0.3          0.016524
#
#                                                       training_time
# poisson_30vars_10000rows  OLS_no_reg                       0.032942
#                           OLS_alpha_1_L1_0                 0.024135
#                           OLS_alpha_1_L1_0.5               0.033962
#                           OLS_alpha_1_L1_1                 0.028598
#                           OLS_alpha_2_L1_0                 0.024075
#                           OLS_alpha_2_L1_0.5               0.029713
#                           OLS_alpha_2_L1_1                 0.031882
#                           OLS_alpha_3_L1_0                 0.023629
#                           OLS_alpha_3_L1_0.5               0.036655
#                           OLS_alpha_3_L1_1                 0.068697
#                           GLM_Poisson_no_reg               0.156787
#                           GLM_Poisson_alpha_0.001          0.774451
#                           GLM_Poisson_alpha_0.01           0.256297
#                           GLM_Poisson_alpha_0.1            0.227372
#                           MLP_50                           0.511894
#                           MLP_20_20                        0.409585
#                           XGB_Poisson_maxd_2_lr_0.01       0.624528
#                           XGB_Poisson_maxd_2_lr_0.3        0.222577
#                           XGB_Poisson_maxd_4_lr_0.01       1.053619
#                           XGB_Poisson_maxd_4_lr_0.3        0.273011
#                           XGB_Poisson_maxd_6_lr_0.01       1.326807
#                           XGB_Poisson_maxd_6_lr_0.3        0.386725
# poisson_100vars_10000rows OLS_no_reg                       0.122580
#                           OLS_alpha_1_L1_0                 0.116124
#                           OLS_alpha_1_L1_0.5               0.114407
#                           OLS_alpha_1_L1_1                 0.118310
#                           OLS_alpha_2_L1_0                 0.115726
#                           OLS_alpha_2_L1_0.5               0.121943
#                           OLS_alpha_2_L1_1                 0.118822
#                           OLS_alpha_3_L1_0                 0.121015
#                           OLS_alpha_3_L1_0.5               0.122969
#                           OLS_alpha_3_L1_1                 0.124781
#                           GLM_Poisson_alpha_0.001          2.836756
#                           GLM_Poisson_alpha_0.01           0.858335
#                           GLM_Poisson_alpha_0.1            0.764165
#                           MLP_50                           1.230091
#                           MLP_20_20                        0.532834
#                           XGB_Poisson_maxd_2_lr_0.01       1.938371
#                           XGB_Poisson_maxd_2_lr_0.3        0.504574
#                           XGB_Poisson_maxd_4_lr_0.01       3.457994
#                           XGB_Poisson_maxd_4_lr_0.3        0.840418
#                           XGB_Poisson_maxd_6_lr_0.01       4.996823
#                           XGB_Poisson_maxd_6_lr_0.3        1.083135
# poisson_30vars_30000rows  OLS_no_reg                       0.067787
#                           OLS_alpha_1_L1_0                 0.065207
#                           OLS_alpha_1_L1_0.5               0.069029
#                           OLS_alpha_1_L1_1                 0.061638
#                           OLS_alpha_2_L1_0                 0.054232
#                           OLS_alpha_2_L1_0.5               0.054438
#                           OLS_alpha_2_L1_1                 0.055212
#                           OLS_alpha_3_L1_0                 0.055766
#                           OLS_alpha_3_L1_0.5               0.054950
#                           OLS_alpha_3_L1_1                 0.054158
#                           GLM_Poisson_no_reg               0.230114
#                           GLM_Poisson_alpha_0.001          1.191450
#                           GLM_Poisson_alpha_0.01           0.715212
#                           GLM_Poisson_alpha_0.1            0.613334
#                           MLP_50                           1.128125
#                           MLP_20_20                        0.544136
#                           XGB_Poisson_maxd_2_lr_0.01       1.846995
#                           XGB_Poisson_maxd_2_lr_0.3        0.767329
#                           XGB_Poisson_maxd_4_lr_0.01       2.659448
#                           XGB_Poisson_maxd_4_lr_0.3        0.983681
#                           XGB_Poisson_maxd_6_lr_0.01       3.051396
#                           XGB_Poisson_maxd_6_lr_0.3        1.160509
# poisson_100vars_30000rows OLS_no_reg                       0.361925
#                           OLS_alpha_1_L1_0                 0.333498
#                           OLS_alpha_1_L1_0.5               0.273280
#                           OLS_alpha_1_L1_1                 0.266611
#                           OLS_alpha_2_L1_0                 0.331798
#                           OLS_alpha_2_L1_0.5               0.270533
#                           OLS_alpha_2_L1_1                 0.274343
#                           OLS_alpha_3_L1_0                 0.332940
#                           OLS_alpha_3_L1_0.5               0.266178
#                           OLS_alpha_3_L1_1                 0.268318
#                           GLM_Poisson_no_reg               2.949946
#                           GLM_Poisson_alpha_0.001          6.810558
#                           GLM_Poisson_alpha_0.01           2.167281
#                           GLM_Poisson_alpha_0.1            1.943577
#                           MLP_50                           1.519968
#                           MLP_20_20                        1.039417
#                           XGB_Poisson_maxd_2_lr_0.01       5.446899
#                           XGB_Poisson_maxd_2_lr_0.3        1.959114
#                           XGB_Poisson_maxd_4_lr_0.01      10.058769
#                           XGB_Poisson_maxd_4_lr_0.3        2.351050
#                           XGB_Poisson_maxd_6_lr_0.01      14.374946
#                           XGB_Poisson_maxd_6_lr_0.3        3.801113
